# %% [markdown]
# <center>
#
# <table style="width: 750px; margin: 0 auto; border-collapse: separate; border-spacing: 0; font-family: Arial, sans-serif;">
# <tr>
# <td style="width: 110px; text-align: center; vertical-align: middle; background-color: #245a77; padding: 22px 12px; border-radius: 16px 0 0 16px;">
# <img src="DCCourse/images/stone.png" width="52" style="display: block; margin: 0 auto;">
# </td>
# <td style="padding: 22px 26px; text-align: left; vertical-align: middle; background-color: #1d6788; border-radius: 0 16px 16px 0;">
# <div style="font-size: 30px; color: #ffffff; font-weight: bold; line-height: 1.3; margin-bottom: 8px;">国际大学生冰壶人工智能挑战赛课程平台</div>
# <div style="font-size: 17px; color: #eef8fb; font-weight: bold; line-height: 1.5; margin-bottom: 10px;">International Collegiate Curling Artificial Intelligence Challenge <br>Course Platform</div>
# <div style="font-size: 14px; color: #e4f2f8; line-height: 1.8;">课程平台汇聚中文教程与英文教程入口，方便课堂教学、比赛培训与国际交流时快速切换。<br>课程按照基础知识、战术与策略、强化学习与搜索方法逐步展开，建议按序阅读和实践。</div>
# </td>
# </tr>
# </table>
#
#
# <div style="width: 750px; margin: 22px auto 0 auto;">
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/01.数字冰壶比赛简介.ipynb" target=_blank>01.数字冰壶比赛简介</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e1.Introduction.ipynb" target=_blank>Introduction to Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/02.数字冰壶比赛中的Socket通信.ipynb">02.数字冰壶比赛中的Socket通信</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e2.SocketCommunication.ipynb" target=_blank>Socket Communication in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/03.数字冰壶比赛中的冰壶运动模型.ipynb">03.数字冰壶比赛中的冰壶运动模型</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e3.CurlingDynamicsModel.ipynb" target=_blank>Curling Dynamics Model in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/04.数字冰壶比赛中的对战策略.ipynb">04.数字冰壶比赛中的对战策略</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e4.BattleStrategies.ipynb" target=_blank>Battle Strategies in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/05.数字冰壶比赛中的战术库使用说明.ipynb">05.数字冰壶比赛中的战术库使用说明</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e5.TacticsLibIntro.ipynb" target=_blank>Tactics Library Usage Guide for Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/06.数字冰壶比赛中强化学习算法的应用.ipynb">06.数字冰壶比赛中强化学习算法的应用</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e6.ReinforcementLearning.ipynb" target=_blank>Reinforcement Learning in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/07.数字冰壶比赛中DQN算法的实现.ipynb">07.数字冰壶比赛中DQN算法的实现</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e7.DQNAlgorithm.ipynb" target=_blank>DQN Algorithm in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/08.数字冰壶比赛中PPO算法的实现.ipynb">08.数字冰壶比赛中PPO算法的实现</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e8.PPOAlgorithm.ipynb" target=_blank>PPO Algorithm in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/09.并行DQN算法及并行PPO算法.ipynb">09.并行DQN算法及并行PPO算法</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/e9.ParallelAlgorithm.ipynb" target=_blank>Parallel DQN Algorithms and Parallel PPO Algorithms</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/10.数字冰壶比赛中MCTS算法的实现.ipynb">10.数字冰壶比赛中MCTS算法的实现</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/ea.MCTSAlgorithm.ipynb" target=_blank>MCTS Algorithm in Digital Curling Competitions</a></div>
# </div>
#
# <div style="width: 100%; box-sizing: border-box; background: linear-gradient(90deg, #ffffff 0%, #f7fbfd 100%); border: 1px solid #d9e6ee; border-radius: 16px; padding: 14px 18px; text-align: left; box-shadow: 0 10px 20px rgba(18, 56, 90, 0.06); margin-bottom: 12px;">
# <div style="font-size: 16px; font-weight: 700; color: #153d5f; margin-bottom: 6px;"><a style="color: #153d5f; text-decoration: none;" href="DCCourse/11.数字冰壶比赛之等你来战.ipynb">11.数字冰壶比赛之等你来战</a></div>
# <div style="text-align: right; font-size: 16px;"><a style="color: #b05b32; text-decoration: none; font-weight: 700;" href="DCCourse/eb.WaitingForYou.ipynb" target=_blank>Digital Curling Competition: Waiting or You to Challenge</a></div>
# </div>
#
# </div>
#
# </center>
